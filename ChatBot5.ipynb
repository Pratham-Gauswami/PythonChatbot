# %%
import getpass
import os
from langchain_cohere import ChatCohere
from langchain_core.messages import HumanMessage

os.environ["D14bT4Bm9SoiXE5ioVryf2DGOyIw1yjm1ccR0giQ"] = getpass.getpass()

chat = ChatCohere(model="command")
messages = [HumanMessage(content="1"), HumanMessage(content="2 3")]
chat.invoke(messages)
AIMessage(content='4 && 5 \n6 || 7 \n\nWould you like to play a game of odds and evens?', additional_kwargs={'documents': None, 'citations': None, 'search_results': None, 'search_queries': None, 'is_search_required': None, 'generation_id': '2076b614-52b3-4082-a259-cc92cd3d9fea', 'token_count': {'prompt_tokens': 68, 'response_tokens': 23, 'total_tokens': 91, 'billed_tokens': 77}}, response_metadata={'documents': None, 'citations': None, 'search_results': None, 'search_queries': None, 'is_search_required': None, 'generation_id': '2076b614-52b3-4082-a259-cc92cd3d9fea', 'token_count': {'prompt_tokens': 68, 'response_tokens': 23, 'total_tokens': 91, 'billed_tokens': 77}}, id='run-3475e0c8-c89b-4937-9300-e07d652455e1-0')

# %%
import getpass
import os
from langchain_cohere import ChatCohere
from langchain_core.messages import HumanMessage

os.environ["COHERE_API_KEY"] = "D14bT4Bm9SoiXE5ioVryf2DGOyIw1yjm1ccR0giQ"
chat = ChatCohere()
messages = [HumanMessage(content="knock knock")]
print(chat.invoke(messages))
# Out:
# content="Who's there?" additional_kwargs={'documents': None, 'citations': None, 'search_results': None, 'search_queries': None, 'is_search_required': None, 'generation_id': 'ff9ce8ac-b125-480f-97a3-f8f9de9f0161', 'token_count': {'input_tokens': 68, 'output_tokens': 4}} response_metadata={'documents': None, 'citations': None, 'search_results': None, 'search_queries': None, 'is_search_required': None, 'generation_id': 'ff9ce8ac-b125-480f-97a3-f8f9de9f0161', 'token_count': {'input_tokens': 68, 'output_tokens': 4}} id='run-abbd57d4-91e9-4304-9730-6db143a971db-0'

# %%
from langchain_community.utilities.sql_database import SQLDatabase

# Assuming you have the correct connection URI for MSSQL
# Replace with your MSSQL database details (server, database, username, password)
db_uri = "mssql+pyodbc://sa:Pratham72@server/Trial1?driver=ODBC+Driver+17+for+SQL+Server"

# Create SQLDatabase object
db = SQLDatabase.from_uri(db_uri)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sqlalchemy/engine/base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3300, in Engine.raw_connection(self)
#    3279 """Return a "raw" DBAPI connection from the connection pool.
#    3280
#    3281 The returned object is a proxied version of the DBAPI
#    (...)
#    3298
#    3299 """
# -> 3300 return self.pool.connect()
#
# ...

# %%
from langchain_community.utilities.sql_database import SQLDatabase
from langchain_community.agent_toolkits import create_sql_agent
from langchain_cohere import ChatCohere

# Replace with your MSSQL server details (username, password, server, database_name)
db_uri = 'mssql+pyodbc://sa:Pratham72@localhost/Trial1?driver=ODBC+Driver+17+for+SQL+Server'


try:
    # Establish database connection
    db = SQLDatabase.from_uri(db_uri)
    print("Database connection established successfully!")

    # Create a Cohere chat instance
    chat_cohere = ChatCohere(api_key="D14bT4Bm9SoiXE5ioVryf2DGOyIw1yjm1ccR0giQ", model="command", max_tokens=256, temperature=0.75)

    # Create SQL agent combining Cohere with SQL database
    agent_executor = create_sql_agent(chat_cohere, db=db, agent_type="cohere-agent", verbose=True)

    # Now you can use 'agent_executor' for further interactions

except Exception as e:
    print(f"Error connecting to database: {e}")

# try:
#     db = SQLDatabase.from_uri(db_uri)
#     # Use 'db' object for further operations
#     print("Database connection established successfully!")
# except Exception as e:
#     print(f"Error connecting to database: {e}")
# Out:
# Database connection established successfully!
# Error connecting to database: Agent type cohere-agent not supported at the moment. Must be one of 'tool-calling', 'openai-tools', 'openai-functions', or 'zero-shot-react-description'.
